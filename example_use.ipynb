# %% [markdown]
# <div class="alert alert-block alert-info" style="text-align: center;">
# <a href="https://colab.research.google.com/github/Pgibby8/SentenceFusion/blob/main/example_use.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a>
# </div>

# %% [markdown]
# # Clone the repo and install transformers

# %%
# !git clone https://github.com/Pgibby8/SentenceFusion.git
# !cd SentenceFusion && pip install .
# !pip install --quiet transformers
# Out:
# Cloning into 'SentenceFusion'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 43 (delta 12), reused 31 (delta 6), pack-reused 0
# Unpacking objects: 100% (43/43), done.
# Processing /content/SentenceFusion
# ...
#   Created wheel for Pgibby8: filename=Pgibby8-0.0.1-cp36-none-any.whl size=2486 sha256=7a88f44476e4787b0435171f275801581a67dd08f968f5bab41897a135a30859
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l961_8rx/wheels/ec/6e/d8/14c184f2b613db4a9d11957066d7b9f8aa7392a6d7571f6403
# Successfully built Pgibby8
# ...
#      |████████████████████████████████| 1.3MB 13.0MB/s
#      |████████████████████████████████| 1.1MB 46.2MB/s
#      |████████████████████████████████| 890kB 36.8MB/s
#      |████████████████████████████████| 2.9MB 48.6MB/s
# ...

# %% [markdown]
# # Import our pre-trained model and its respective tokenizer

# %%
from transformers import EncoderDecoderModel, BertTokenizer

bert2bert = EncoderDecoderModel.from_pretrained('ralcanta/do_nothing_bert')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %% [markdown]
# ### Initialize a fuser

# %%
from SentenceFusion import sentence_fusion as sf

fuser = sf.SentenceFusion(tokenizer, bert2bert)

# %% [markdown]
# See the magic! Feel free to change the value of `delta` to see different results.

# %%
primary_sentence = "I have two cute dogs"
secondary_sentence = "to be or not to be, that is the question"
fuser.fuse(primary_sentence, secondary_sentence, delta=.5)
# Out:
# ['i have two cute cute dogs i has two adorable dogs they have three cute dog dogs one cute']
